# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_path = Path('Resources/whale_returns.csv')
whale_df = pd.read_csv(whale_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algor_path = Path('Resources/algo_returns.csv')
algor_df = pd.read_csv(algor_path, infer_datetime_format=True, parse_dates=True, index_col='Date')
algor_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algor_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algor_df.dropna(inplace=True)
algor_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_path = Path('Resources/sp500_history.csv')
sp500_df = pd.read_csv(sp500_path, infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df['Close'] = sp500_df['Close'].str.replace('$', '')
sp500_df['Close'] = sp500_df['Close'].astype('float')
sp500_df.head()
# Out:
# /var/folders/3n/82qdfqn13gzc03m31zz_p0l00000gp/T/ipykernel_22601/3602813632.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp500_df['Close'] = sp500_df['Close'].str.replace('$', '')
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
# Calculate Daily Returns
sp500_daily_returns = sp500_df.pct_change()
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
sp500_daily_returns.dropna(inplace=True)
sp500_daily_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_daily_returns.columns = ['S&P 500 Returns']
sp500_daily_returns.head()
# Out:
#             S&P 500 Returns
# Date
# 2019-04-22        -0.008764
# 2019-04-18        -0.001011
# 2019-04-17        -0.001577
# 2019-04-16         0.002279
# 2019-04-15        -0.000509

# %%
#Resorting to ascending dates to match the other dataframes 
sp500_daily_returns = sp500_daily_returns.sort_index(ascending=True)
sp500_daily_returns.head()
# Out:
#             S&P 500 Returns
# Date
# 2012-10-01        -0.000872
# 2012-10-02        -0.003611
# 2012-10-03        -0.007123
# 2012-10-04         0.000322
# 2012-10-05         0.003469

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
big_df = pd.concat([whale_df, algor_df, sp500_daily_returns], axis='columns', join='inner')
big_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  S&P 500 Returns
# Date
# 2015-03-03 -0.000949         0.004408
# 2015-03-04  0.002416        -0.001195
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
big_daily_returns = big_df.pct_change()
big_daily_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + big_daily_returns).cumprod()-1
# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
# whale
whale_df.plot(figsize=(20,10), kind='box')
# Out:
# <AxesSubplot:>

# %%
# algo
algor_df.plot(figsize=(20,10), kind='box')
# Out:
# <AxesSubplot:>

# %%
# S&P 500 Returns
sp500_daily_returns.plot(figsize=(20,10), kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
whale_std = whale_df.std()
whale_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64

# %%
# Algo Standard Deviation
algor_std = algor_df.std()
algor_std
# Out:
# Algo 1    0.007988
# Algo 2    0.008466
# dtype: float64

# %%
# S&P 500 Standard Deviation
sp500_std = sp500_daily_returns.std()
sp500_std
# Out:
# S&P 500 Returns    0.008135
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Average Standard Deviation
whale_avg_std = whale_std.mean(axis=0)
algor_avg_std = algor_std.mean(axis=0)
sp500_avg_std = sp500_std[0]

# The greater the standard deviation, the greater the risk 

# Determine which portfolios are riskier than the S&P 500

if (whale_avg_std > sp500_avg_std) and (algor_avg_std > sp500_std[0]):
    print(f'Both the Whale portfolio and the Algo portfolio are riskier than the S&P 500.')
elif whale_avg_std > sp500_avg_std:
    print(f'The Whale portfolio is riskier than the S&P 500.')
elif algor_avg_std > sp500_avg_std:
    print(f'The Algo portfolio is riskier than the S&P 500.')
else:
    print(f'Neither portfolio is riskier than the S&P 500.')
# Out:
# Both the Whale portfolio and the Algo portfolio are riskier than the S&P 500.

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)

# Whale Annualized Standard Deviation
whale_annual_std = whale_avg_std * np.sqrt(252)
# Algo Annualized Standard Deviation
algor_annual_std = algor_avg_std * np.sqrt(252)
# S&P 500 Annualized Standard Deviation
sp500_annual_std = sp500_avg_std * np.sqrt(252)


print('The annualized standard deviation for the Whale portfolio is: ' , whale_annual_std)
print('The annualized standard deviation for the Algo portfolio is: ' , algor_annual_std)
print('The annualized standard deviation for the S&P 500 portfolio is: ' , sp500_annual_std)
# Out:
# The annualized standard deviation for the Whale portfolio is:  0.15268850476046356
# The annualized standard deviation for the Algo portfolio is:  0.13060096487608586
# The annualized standard deviation for the S&P 500 portfolio is:  0.12913344822666875

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
big_rolling_std = big_daily_returns.rolling(window=21).std()
# Plot the rolling standard deviation
big_rolling_std.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
price_correlation = big_daily_returns.corr()
# Display de correlation matrix
price_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.002892
# PAULSON & CO.INC.                             0.002892            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.022256            0.035635
# BERKSHIRE HATHAWAY INC                        0.000333            0.002154
# Algo 1                                        0.000064            0.006378
# Algo 2                                       -0.005758            0.010882
# S&P 500 Returns                               0.040058            0.002567
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.022256
# PAULSON & CO.INC.                               0.035635
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                         -0.014025
# Algo 1                                          0.003367
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
import seaborn as sns

sns.heatmap(price_correlation, vmin=-0.05, vmax=0.05)
# Out:
# <AxesSubplot:>

# %%
# Calculate covariance of a single portfolio
cov_tiger = big_df['TIGER GLOBAL MANAGEMENT LLC'].rolling(window=30).cov(big_df['S&P 500 Returns'])

# Calculate variance of S&P 500
var_sp500 = big_df['S&P 500 Returns'].rolling(window=30).var()

# Computing beta
tiger_beta = cov_tiger / var_sp500

# Plot beta trend
tiger_beta.plot(legend=(20,10), title = 'Tiger Global Rolling Beta')
# Out:
# <AxesSubplot:title={'center':'Tiger Global Rolling Beta'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
ewm = big_df.ewm(halflife=21).std()
ewm.plot(figsize=(20,10), title='Exponentially Weighted Average')
# Out:
# <AxesSubplot:title={'center':'Exponentially Weighted Average'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratio = ((big_df.mean())*252) / (big_df.std() * np.sqrt(252))
sharpe_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# S&P 500 Returns               -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind='bar', figsize = (20,10), title='Sharpe Ratios')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# From what I can tell the algorithmic strategies outperformed the S&P 500 and the whale portfolios. Algo 1 outperforms Algo 2. Algo 2 barely outperforms the whale portfolios.

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
AMZN_path = Path('Resources/AMZN.csv')

#setting datetime index 
AMZN_df = pd.read_csv(AMZN_path, delimiter= ',', infer_datetime_format=True, parse_dates=True, index_col='Date')

#renaming "close" to "AMZN" for when we comine the dataframes 
AMZN_df = AMZN_df.rename(columns={
    'Close' : 'AMZN'
})
AMZN_df.head()
# Out:
#                    Open         High          Low         AMZN    Adj Close  \
# Date
# 2021-01-19  3107.000000  3145.000000  3096.000000  3120.760010  3120.760010
# 2021-01-20  3181.989990  3279.800049  3175.000000  3263.379883  3263.379883
# 2021-01-21  3293.000000  3348.550049  3289.570068  3306.989990  3306.989990
# 2021-01-22  3304.310059  3321.909912  3283.159912  3292.229980  3292.229980
# 2021-01-25  3328.500000  3363.889893  3243.149902  3294.000000  3294.000000
#
#              Volume
# Date
# 2021-01-19  3305100
# 2021-01-20  5309800
# 2021-01-21  4936100
# 2021-01-22  2821900
# 2021-01-25  3749800

# %%
# Reading data from 2nd stock
GME_path = Path('Resources/GME.csv')

#setting datetime index 
GME_df = pd.read_csv(GME_path, delimiter= ',', infer_datetime_format=True, parse_dates=True, index_col='Date')

#renaming "close" to "AMZN" for when we comine the dataframes 
GME_df = GME_df.rename(columns={
    'Close' : 'GME'
})
GME_df.head()
# Out:
#                  Open        High        Low        GME  Adj Close     Volume
# Date
# 2021-01-19  41.549999   45.520000  36.639999  39.360001  39.360001   74721900
# 2021-01-20  37.369999   41.189999  36.060001  39.119999  39.119999   33471800
# 2021-01-21  39.230000   44.750000  37.000000  43.029999  43.029999   56216900
# 2021-01-22  42.590000   76.760002  42.320000  65.010002  65.010002  197157900
# 2021-01-25  96.730003  159.179993  61.130001  76.790001  76.790001  177874000

# %%
# Reading data from 3rd stock
TSLA_path = Path('Resources/TSLA.csv')

#setting datetime index 
TSLA_df = pd.read_csv(TSLA_path, delimiter= ',', infer_datetime_format=True, parse_dates=True, index_col='Date')

#renaming "close" to "AMZN" for when we comine the dataframes 
TSLA_df = TSLA_df.rename(columns={
    'Close' : 'TSLA'
})
TSLA_df.head()
# Out:
#                   Open        High         Low        TSLA   Adj Close  \
# Date
# 2021-01-19  837.799988  850.000000  833.000000  844.549988  844.549988
# 2021-01-20  858.739990  859.500000  837.280029  850.450012  850.450012
# 2021-01-21  855.000000  855.719971  841.419983  844.989990  844.989990
# 2021-01-22  834.309998  848.000000  828.619995  846.640015  846.640015
# 2021-01-25  855.000000  900.400024  838.820007  880.799988  880.799988
#
#               Volume
# Date
# 2021-01-19  25367000
# 2021-01-20  25665900
# 2021-01-21  20521100
# 2021-01-22  20066500
# 2021-01-25  41173400

# %%
# Combine all stocks in a single DataFrame
custom_portfolio_df = pd.concat([AMZN_df, GME_df, TSLA_df], axis='columns', join='inner')
custom_portfolio_df = custom_portfolio_df.drop(columns=['Open', 'High', 'Low', 'Adj Close', 'Volume'])
custom_portfolio_df.head()
# Out:
#                    AMZN        GME        TSLA
# Date
# 2021-01-19  3120.760010  39.360001  844.549988
# 2021-01-20  3263.379883  39.119999  850.450012
# 2021-01-21  3306.989990  43.029999  844.989990
# 2021-01-22  3292.229980  65.010002  846.640015
# 2021-01-25  3294.000000  76.790001  880.799988

# %%
# Calculate daily returns
custom_daily_returns = custom_portfolio_df.pct_change()

# Drop NAs
custom_daily_returns = custom_daily_returns.dropna() 

# Display sample data
custom_daily_returns.head()
# Out:
#                 AMZN       GME      TSLA
# Date
# 2021-01-20  0.045700 -0.006098  0.006986
# 2021-01-21  0.013363  0.099949 -0.006420
# 2021-01-22 -0.004463  0.510806  0.001953
# 2021-01-25  0.000538  0.181203  0.040348
# 2021-01-26  0.009754  0.927074  0.002600

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
custom_returns = custom_daily_returns.dot(weights)

# Display sample data
custom_returns.head()
# Out:
# Date
# 2021-01-20    0.015530
# 2021-01-21    0.035631
# 2021-01-22    0.169432
# 2021-01-25    0.074029
# 2021-01-26    0.313143
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
big_df['Custom Returns'] = custom_returns
big_df
# I'm not sure why my custom returns are showing as null values...
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annual_std = big_df.std() * np.sqrt(252)
annual_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# S&P 500 Returns                0.136313
# Custom Returns                      NaN
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_portfolio_std = big_df.rolling(window=21).std()
# Plot rolling standard deviation
rolling_portfolio_std.plot(figsize=(20,10), title = '21-day Rolling Standard Deviation')
# Out:
# <AxesSubplot:title={'center':'21-day Rolling Standard Deviation'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation_portfolio = rolling_portfolio_std.corr()
sns.heatmap(correlation_portfolio, vmin=-0, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
#covariance
cov_custom_portfolio = big_df['Custom Returns'].rolling(window=60).cov(big_df['S&P 500 Returns'])

#variance
var_custom_portfolio = big_df['S&P 500 Returns'].rolling(window=60).var()

#beta
custom_portfolio_beta = cov_custom_portfolio / var_custom_portfolio

#plotting
custom_portfolio_beta.plot(figsize = (20,10), title = '60-day Rolling Beta for Custom Portfolio versus S&P 500')
# Out:
# <AxesSubplot:title={'center':'60-day Rolling Beta for Custom Portfolio versus S&P 500'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
portfolio_sharpe_ratios = ((big_df.mean()) * 252) / (big_df.std() * np.sqrt(252))
portfolio_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# S&P 500 Returns               -0.518582
# Custom Returns                      NaN
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
portfolio_sharpe_ratios.plot(kind='bar', figsize = (20,10), title = 'Sharpe Ratios for portfolios')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios for portfolios'}>

# %% [markdown]
# ### How does your portfolio do?
#
#
# I'm not sure why my Custom Portfolio was returning a null value after I joined my dataframes... The dates seemed to match in format for my custom portfolio and the others, but I was having trouble getting them joined correctly for some reason. I tried to finsih the best I could, but obviously my plots do not look how they are supposed to :-( I plan on getting some assistance to figure out where I went wrong with joining my dataframes, but overall this assignment was incredibly fun and challenging. I'm excited to figure out where my misstep was and to learn more!
